# %%
# Essential libraries
import numpy as np
import pandas as pd
import matplotlib

# %%
# Imports relevant CSVs
housing_df = pd.read_csv("SD1970_housing.csv")
population_df = pd.read_csv("SD1970_population.csv")

# %%
housing_df.head()
# Out:
#            Tract name  Block group Place Name Total housing units  \
# 0  Census Tract 1                1  San Diego                 302
# 1  Census Tract 1                2  San Diego                 234
# 2  Census Tract 1                3  San Diego                 176
# 3  Census Tract 1                4  San Diego                 159
# 4  Census Tract 1                5  San Diego                 209
#
#   Total owner occupied real $ aggregate (total) value of housing units  \
# 0                                     $7,783,750.00
# 1                                     $5,720,000.00
# 2                                     $5,721,250.00
# 3                                     $5,633,750.00
# 4                                     $5,815,000.00
#
#   Black owner occupied real $ aggregate (total) value of housing units  \
# 0                                                ...
# 1                                                ...
# ...

# %%
population_df.head()
# Out:
#     Census Tract Name  Block Group Place Name Total persons  \
# 0  Census Tract 1                1  San Diego           901
# 1  Census Tract 1                2  San Diego           683
# 2  Census Tract 1                3  San Diego           532
# 3  Census Tract 1                4  San Diego           421
# 4  Census Tract 1                5  San Diego           489
#
#   Male persons age under 5 years Male persons age 5 years  \
# 0                             31                        6
# 1                             28                        2
# 2                             18                        4
# 3                              9                        3
# 4                             12                        2
#
#   Male persons age 6 years Male persons age 7-9 years  \
# 0                        9                         29
# 1                        9                         14
# 2                        4                         15
# ...

# %%
# finding total gender columns 
population_df.replace("...", 0)

for column in population_df.columns:
    population_df[column] = population_df[column].apply(lambda value: int(value) if (isinstance(value, str) and value.isdigit()) else value)

male = population_df.iloc[:,population_df.columns.str.startswith('Male persons age')]
female = population_df.iloc[:,population_df.columns.str.startswith('Female persons age')]
blackmale = population_df.iloc[:,population_df.columns.str.startswith('Black male persons age')]
blackfemale = population_df.iloc[:,population_df.columns.str.startswith('Black female persons age')]


male_cols = population_df.iloc[:,population_df.columns.str.startswith('Male persons age')]
female_cols = population_df.iloc[:,population_df.columns.str.startswith('Female persons age')]
blackmale_cols = population_df.iloc[:,population_df.columns.str.startswith('Black male persons age')]  
blackfemale_cols = population_df.iloc[:,population_df.columns.str.startswith('Black female persons age')]

population_df["Total Male Persons"] = male.sum(axis=1)
population_df["Total Female Persons"] = female.sum(axis=1)
population_df["Total Black Male Persons"] = blackmale.sum(axis=1)
population_df["Total Black Female Persons"] = blackfemale.sum(axis=1)

population_df2 = population_df.drop(list(female_cols) + list(male_cols) + list(blackmale_cols) + list(blackfemale_cols), axis=1)
#population_df3 = population_df2.drop(list(male_cols), axis=1)

population_df2[population_df2.get('Total Black Male Persons') != '........................']
# Out:
#        Census Tract Name  Block Group  Place Name Total persons  \
# 10    Census Tract 2                4   San Diego           960
# 14    Census Tract 3                1   San Diego           885
# 15    Census Tract 3                2   San Diego           362
# 18    Census Tract 4                1   San Diego         2,145
# 19    Census Tract 4                2   San Diego           826
# ...                  ...          ...         ...           ...
# 1227  Census Tract 194              1   Oceanside             0
# 1229  Census Tract 194              2       Vista           991
# 1232  Census Tract 194              5       Vista           680
# 1238  Census Tract 195              4       Vista         2,175
# 1253  Census Tract 199              1  San Marcos             0
#
#      Other nonwhite races male age under 5 years  \
# 10                                             0
# 14                                             0
# ...
